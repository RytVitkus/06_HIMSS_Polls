# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# **We would like to see analysis of:**
#
#
#
# - Presidents Approval
# - General Election
# - **US Senate**
# - **US House**
# - **Governor**
# - Generic Ballot (optional)
#
#
# Please provide the analysis in a format of your choosing (not looking for specific formats, looking specifically for data analysis). If there are any questions around the data set, please include those questions with the analysis.
#
# Files to be used:
# <br>
# > `president_approval_polls.csv` <br>
# > `president_polls.csv` <br>
# > `generic_ballot_polls.csv` <br>
# > `president_primary_polls.csv` <br>
# > `senate_polls.csv` <br>
# > `house_polls.csv` <br>
# > `governor_polls.csv` <br>
# > `president_primary_polls` <br>
# > `presidential_poll_averages_2020.csv` <br>

# %%
#code
def floatify(x):
    try:
        return float(int(x.replace("%",'')))
    except:
        return x
    
def eda(dataframe):
    print("Missing Values \n \n", dataframe.isnull().sum(),"\n")
    print("Duplicate Rows \n", dataframe.duplicated().sum(),"\n")
    print("Dataframe Types \n \n", dataframe.dtypes,"\n")
    print("Dataframe Shape \n", dataframe.shape,"\n")
    print("Dataframe Describe \n \n", dataframe.describe(include='all'),"\n")
    for item in dataframe:
        print(item)

# %%
df_senate = pd.read_csv('polls/senate_polls.csv')
df_house = pd.read_csv('polls/house_polls.csv')
df_gov = pd.read_csv('polls/governor_polls.csv')

df_list = [df_senate, df_house, df_gov]

# %%
for frame in df_list:
    display(frame.head())
# Out:
#    question_id  poll_id  cycle           state  pollster_id               pollster sponsor_ids sponsors           display_name  pollster_rating_id   pollster_rating_name fte_grade  sample_size population population_full methodology  office_type  seat_number seat_name start_date end_date election_date sponsor_candidate  internal partisan tracking  nationwide_batch  ranked_choice_reallocated     created_at notes                                                url    stage  race_id     answer  candidate_id    candidate_name candidate_party   pct
# 0       129448    69487   2020        Kentucky          396  Quinnipiac University         NaN      NaN  Quinnipiac University                 267  Quinnipiac University        B+       1164.0         lv              lv  Live Phone  U.S. Senate            0  Class II    9/10/20  9/14/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/16/20 14:21   NaN  https://poll.qu.edu/kentucky/release-detail?Re...  general     6276    McGrath         13470       Amy McGrath             DEM  41.0
# 1       129448    69487   2020        Kentucky          396  Quinnipiac University         NaN      NaN  Quinnipiac University                 267  Quinnipiac University        B+       1164.0         lv              lv  Live Phone  U.S. Senate            0  Class II    9/10/20  9/14/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/16/20 14:21   NaN  https://poll.qu.edu/kentucky/release-detail?Re...  general     6276  McConnell         13471   Mitch McConnell             REP  53.0
# 2       129449    69488   2020           Maine          396  Quinnipiac University         NaN      NaN  Quinnipiac University                 267  Quinnipiac University        B+       1183.0         lv              lv  Live Phone  U.S. Senate            2  Class II    9/10/20  9/14/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/16/20 14:21   NaN  https://poll.qu.edu/kentucky/release-detail?Re...  general     6279     Gideon         13455       Sara Gideon             DEM  54.0
# 3       129449    69488   2020           Maine          396  Quinnipiac University         NaN      NaN  Quinnipiac University                 267  Quinnipiac University        B+       1183.0         lv              lv  Live Phone  U.S. Senate            2  Class II    9/10/20  9/14/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/16/20 14:21   NaN  https://poll.qu.edu/kentucky/release-detail?Re...  general     6279    Collins         13456  Susan M. Collins             REP  42.0
# 4       129450    69491   2020  South Carolina          396  Quinnipiac University         NaN      NaN  Quinnipiac University                 267  Quinnipiac University        B+        969.0         lv              lv  Live Phone  U.S. Senate            0  Class II    9/10/20  9/14/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/16/20 14:21   NaN  https://poll.qu.edu/kentucky/release-detail?Re...  general     6292   Harrison         13457    Jaime Harrison             DEM  48.0
#    question_id  poll_id  cycle       state  pollster_id      pollster sponsor_ids                                        sponsors  display_name  pollster_rating_id pollster_rating_name fte_grade  sample_size population population_full      methodology office_type  seat_number    seat_name start_date end_date election_date sponsor_candidate  internal partisan  tracking  nationwide_batch  ranked_choice_reallocated     created_at notes                                                url    stage  race_id   answer  candidate_id candidate_name candidate_party   pct
# 0       129392    69470   2020  California          460     SurveyUSA     443,804  KGTV-TV (California) | San Diego Union-Tribune     SurveyUSA               325.0            SurveyUSA         A        517.0         lv              lv       IVR/Online  U.S. House           49  District 49    9/11/20  9/14/20       11/3/20               NaN     False      NaN       NaN             False                      False  9/15/20 20:46   NaN  http://www.surveyusa.com/client/PollReport.asp...  general     7898    Levin         14899     Mike Levin             DEM  49.0
# 1       129392    69470   2020  California          460     SurveyUSA     443,804  KGTV-TV (California) | San Diego Union-Tribune     SurveyUSA               325.0            SurveyUSA         A        517.0         lv              lv       IVR/Online  U.S. House           49  District 49    9/11/20  9/14/20       11/3/20               NaN     False      NaN       NaN             False                      False  9/15/20 20:46   NaN  http://www.surveyusa.com/client/PollReport.asp...  general     7898  Maryott         14900  Brian Maryott             REP  37.0
# 2       129330    69438   2020        Utah         1554  RMG Research         400                                    Deseret News  RMG Research               555.0         RMG Research       B/C        800.0         lv              lv  IVR/Online/Text  U.S. House            4   District 4     9/7/20  9/12/20       11/3/20               NaN     False      NaN       NaN             False                      False  9/14/20 13:01   NaN  https://www.deseret.com/utah/2020/9/14/2143622...  general     8235  McAdams         13565    Ben McAdams             DEM  45.0
# 3       129330    69438   2020        Utah         1554  RMG Research         400                                    Deseret News  RMG Research               555.0         RMG Research       B/C        800.0         lv              lv  IVR/Online/Text  U.S. House            4   District 4     9/7/20  9/12/20       11/3/20               NaN     False      NaN       NaN             False                      False  9/14/20 13:01   NaN  https://www.deseret.com/utah/2020/9/14/2143622...  general     8235    Owens         14704  Burgess Owens             REP  41.0
# 4       129330    69438   2020        Utah         1554  RMG Research         400                                    Deseret News  RMG Research               555.0         RMG Research       B/C        800.0         lv              lv  IVR/Online/Text  U.S. House            4   District 4     9/7/20  9/12/20       11/3/20               NaN     False      NaN       NaN             False                      False  9/14/20 13:01   NaN  https://www.deseret.com/utah/2020/9/14/2143622...  general     8235   Molnar         14705    John Molnar             LIB   2.0
#    question_id  poll_id  cycle           state  pollster_id   pollster sponsor_ids   sponsors display_name  pollster_rating_id pollster_rating_name fte_grade  sample_size population population_full methodology office_type  seat_number  seat_name start_date end_date election_date sponsor_candidate  internal partisan tracking  nationwide_batch  ranked_choice_reallocated     created_at notes                                                url    stage  race_id   answer  candidate_id  candidate_name candidate_party   pct
# 0       129338    69444   2020  North Carolina          460  SurveyUSA         241  WRAL News    SurveyUSA               325.0            SurveyUSA         A          596         lv              lv      Online    Governor            0        NaN    9/10/20  9/13/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/14/20 18:06   NaN  http://www.surveyusa.com/client/PollReport.asp...  general     7824   Cooper         13404   Roy A. Cooper             DEM  49.0
# 1       129338    69444   2020  North Carolina          460  SurveyUSA         241  WRAL News    SurveyUSA               325.0            SurveyUSA         A          596         lv              lv      Online    Governor            0        NaN    9/10/20  9/13/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/14/20 18:06   NaN  http://www.surveyusa.com/client/PollReport.asp...  general     7824   Forest         13406      Dan Forest             REP  42.0
# 2       129371    69462   2020  North Carolina         1361       SSRS         143        CNN     CNN/SSRS               297.0                 SSRS       B/C          893         rv              rv  Live Phone    Governor            0        NaN     9/9/20  9/13/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/15/20 12:12   NaN  https://cdn.cnn.com/cnn/2020/images/09/15/rel1...  general     7824   Cooper         13404   Roy A. Cooper             DEM  53.0
# 3       129371    69462   2020  North Carolina         1361       SSRS         143        CNN     CNN/SSRS               297.0                 SSRS       B/C          893         rv              rv  Live Phone    Governor            0        NaN     9/9/20  9/13/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/15/20 12:12   NaN  https://cdn.cnn.com/cnn/2020/images/09/15/rel1...  general     7824   Forest         13406      Dan Forest             REP  42.0
# 4       129371    69462   2020  North Carolina         1361       SSRS         143        CNN     CNN/SSRS               297.0                 SSRS       B/C          893         rv              rv  Live Phone    Governor            0        NaN     9/9/20  9/13/20       11/3/20               NaN     False      NaN      NaN             False                      False  9/15/20 12:12   NaN  https://cdn.cnn.com/cnn/2020/images/09/15/rel1...  general     7824  DiFiore         14555  Steven DiFiore             LIB   2.0

# %%
for frame in df_list:
    display(frame.shape)
# Out:
# (2967, 38)
# (2238, 38)
# (1949, 38)

# %%
# Senate
eda(df_list[0])
# Out:
# Missing Values
#
#  question_id                     0
# poll_id                         0
# cycle                           0
# state                           0
# pollster_id                     0
# pollster                        0
# sponsor_ids                  1294
# sponsors                     1294
# display_name                    0
# pollster_rating_id              0
# pollster_rating_name            0
# fte_grade                     272
# sample_size                     2
# population                      4
# population_full                 4
# methodology                   367
# office_type                     0
# seat_number                     0
# seat_name                       0
# start_date                      0
# end_date                        0
# election_date                   0
# sponsor_candidate            2787
# internal                        0
# partisan                     2406
# tracking                     2873
# nationwide_batch                0
# ranked_choice_reallocated       0
# created_at                      0
# notes                        2642
# url                             2
# stage                           0
# race_id                         0
# answer                          0
# candidate_id                    0
# candidate_name                  0
# candidate_party                 0
# pct                             0
# dtype: int64
#
# Duplicate Rows
#  0
#
# Dataframe Types
#
#  question_id                    int64
# poll_id                        int64
# cycle                          int64
# state                         object
# pollster_id                    int64
# pollster                      object
# sponsor_ids                   object
# sponsors                      object
# display_name                  object
# pollster_rating_id             int64
# pollster_rating_name          object
# fte_grade                     object
# sample_size                  float64
# population                    object
# population_full               object
# methodology                   object
# office_type                   object
# seat_number                    int64
# seat_name                     object
# start_date                    object
# end_date                      object
# election_date                 object
# sponsor_candidate             object
# internal                        bool
# partisan                      object
# tracking                      object
# nationwide_batch                bool
# ranked_choice_reallocated       bool
# created_at                    object
# notes                         object
# url                           object
# stage                         object
# race_id                        int64
# answer                        object
# candidate_id                   int64
# candidate_name                object
# candidate_party               object
# pct                          float64
# dtype: object
#
# Dataframe Shape
#  (2967, 38)
#
# Dataframe Describe
#
#            question_id       poll_id        cycle    state  pollster_id      pollster sponsor_ids sponsors  display_name  pollster_rating_id pollster_rating_name fte_grade  sample_size population population_full methodology  office_type  seat_number seat_name start_date end_date election_date sponsor_candidate internal partisan tracking nationwide_batch ranked_choice_reallocated     created_at                notes                                                url    stage      race_id   answer  candidate_id  candidate_name candidate_party          pct
# count     2967.000000   2967.000000  2967.000000     2967  2967.000000          2967        1673     1673          2967         2967.000000                 2967      2695  2965.000000       2963            2963        2600         2967  2967.000000      2967       2967     2967          2967               180     2967      561       94             2967                      2967           2967                  325                                               2965     2967  2967.000000     2967   2967.000000            2967            2967  2967.000000
# unique            NaN           NaN          NaN       45          NaN           177         164      164           185                 NaN                  177        13          NaN          4               4          14            1          NaN         3        388      385             4                34        2        4        1                1                         1            691                   53                                                838        3          NaN      216           NaN             226              11          NaN
# top               NaN           NaN          NaN  Arizona          NaN  SurveyMonkey         788    Axios  SurveyMonkey                 NaN         SurveyMonkey       B/C          NaN         lv              lv  Live Phone  U.S. Senate          NaN   Class I    6/11/18   7/2/18       11/6/18      Doug Collins    False      DEM     True            False                     False  8/23/18 22:49  2016 model lv model  https://drive.google.com/file/d/1aerd3_1pJ276A...  general          NaN  McSally           NaN  Martha McSally             DEM          NaN
# freq              NaN           NaN          NaN      315          NaN           206         198      198           206                 NaN                  206       734          NaN       1979            1979        1044         2967          NaN      1848        186      186          1927                42     2752      280       94             2967                      2967             58                   30                                                158     2760          NaN      123           NaN             123            1353          NaN
# mean    100109.656892  58836.028986  2018.684867      NaN   950.298618           NaN         NaN      NaN           NaN          262.668015                  NaN       NaN   850.113997        NaN             NaN         NaN          NaN     0.447590       NaN        NaN      NaN           NaN               NaN      NaN      NaN      NaN              NaN                       NaN            NaN                  NaN                                                NaN      NaN  2344.245703      NaN  12466.734749             NaN             NaN    38.501796
# std      16890.140031   5649.518597     0.949207      NaN   448.882966           NaN         NaN      NaN           NaN          147.162978                  NaN       NaN   432.704394        NaN             NaN         NaN          NaN     0.833713       NaN        NaN      NaN           NaN               NaN      NaN      NaN      NaN              NaN                       NaN            NaN                  NaN                                                NaN      NaN  3056.053825      NaN   1144.741360             NaN             NaN    14.806480
# min      83156.000000  52596.000000  2018.000000      NaN    23.000000           NaN         NaN      NaN           NaN            9.000000                  NaN       NaN   169.000000        NaN             NaN         NaN          NaN     0.000000       NaN        NaN      NaN           NaN               NaN      NaN      NaN      NaN              NaN                       NaN            NaN                  NaN                                                NaN      NaN    96.000000      NaN  11125.000000             NaN             NaN     0.000000
# 25%      86751.500000  53920.000000  2018.000000      NaN   502.500000           NaN         NaN      NaN           NaN          133.000000                  NaN       NaN   600.000000        NaN             NaN         NaN          NaN     0.000000       NaN        NaN      NaN           NaN               NaN      NaN      NaN      NaN              NaN                       NaN            NaN                  NaN                                                NaN      NaN   107.000000      NaN  11227.000000             NaN             NaN    36.000000
# 50%      90885.000000  56499.000000  2018.000000      NaN  1102.000000           NaN         NaN      NaN           NaN          263.000000                  NaN       NaN   772.000000        NaN             NaN         NaN          NaN     0.000000       NaN        NaN      NaN           NaN               NaN      NaN      NaN      NaN              NaN                       NaN            NaN                  NaN                                                NaN      NaN   120.000000      NaN  12413.000000             NaN             NaN    43.000000
# 75%     120900.000000  65227.000000  2020.000000      NaN  1361.000000           NaN         NaN      NaN           NaN          338.000000                  NaN       NaN   985.000000        NaN             NaN         NaN          NaN     0.000000       NaN        NaN      NaN           NaN               NaN      NaN      NaN      NaN              NaN                       NaN            NaN                  NaN                                                NaN      NaN  6275.000000      NaN  13454.000000             NaN             NaN    47.300000
# max     129450.000000  69491.000000  2020.000000      NaN  1620.000000           NaN         NaN      NaN           NaN          616.000000                  NaN       NaN  5778.000000        NaN             NaN         NaN          NaN     2.000000       NaN        NaN      NaN           NaN               NaN      NaN      NaN      NaN              NaN                       NaN            NaN                  NaN                                                NaN      NaN  7781.000000      NaN  15852.000000             NaN             NaN    75.000000
#
# question_id
# poll_id
# cycle
# state
# pollster_id
# pollster
# sponsor_ids
# sponsors
# display_name
# pollster_rating_id
# pollster_rating_name
# fte_grade
# sample_size
# population
# population_full
# methodology
# office_type
# seat_number
# seat_name
# start_date
# end_date
# election_date
# sponsor_candidate
# internal
# partisan
# tracking
# nationwide_batch
# ranked_choice_reallocated
# created_at
# notes
# url
# stage
# race_id
# answer
# candidate_id
# candidate_name
# candidate_party
# pct

# %%
# House
eda(df_list[1])
# Out:
# Missing Values
#
#  question_id                     0
# poll_id                         0
# cycle                           0
# state                           0
# pollster_id                     0
# pollster                        0
# sponsor_ids                  1099
# sponsors                     1099
# display_name                    0
# pollster_rating_id              5
# pollster_rating_name            5
# fte_grade                     165
# sample_size                     2
# population                      0
# population_full                 0
# methodology                   591
# office_type                     0
# seat_number                     0
# seat_name                       0
# start_date                      0
# end_date                        0
# election_date                   0
# sponsor_candidate            1726
# internal                        0
# partisan                     1341
# tracking                     2238
# nationwide_batch                0
# ranked_choice_reallocated       0
# created_at                      0
# notes                        1857
# url                             2
# stage                           0
# race_id                         0
# answer                          0
# candidate_id                    0
# candidate_name                  0
# candidate_party                 0
# pct                             0
# dtype: int64
#
# Duplicate Rows
#  0
#
# Dataframe Types
#
#  question_id                    int64
# poll_id                        int64
# cycle                          int64
# state                         object
# pollster_id                    int64
# pollster                      object
# sponsor_ids                   object
# sponsors                      object
# display_name                  object
# pollster_rating_id           float64
# pollster_rating_name          object
# fte_grade                     object
# sample_size                  float64
# population                    object
# population_full               object
# methodology                   object
# office_type                   object
# seat_number                    int64
# seat_name                     object
# start_date                    object
# end_date                      object
# election_date                 object
# sponsor_candidate             object
# internal                        bool
# partisan                      object
# tracking                     float64
# nationwide_batch                bool
# ranked_choice_reallocated       bool
# created_at                    object
# notes                         object
# url                           object
# stage                         object
# race_id                        int64
# answer                        object
# candidate_id                   int64
# candidate_name                object
# candidate_party               object
# pct                          float64
# dtype: object
#
# Dataframe Shape
#  (2238, 38)
#
# Dataframe Describe
#
#            question_id       poll_id       cycle       state  pollster_id                                 pollster sponsor_ids        sponsors                             display_name  pollster_rating_id                     pollster_rating_name fte_grade  sample_size population population_full methodology office_type  seat_number   seat_name start_date end_date election_date sponsor_candidate internal partisan  tracking nationwide_batch ranked_choice_reallocated      created_at                   notes                                                url    stage      race_id answer  candidate_id candidate_name candidate_party          pct
# count     2238.000000   2238.000000  2238.00000        2238  2238.000000                                     2238        1139            1139                                     2238         2233.000000                                     2233      2073  2236.000000       2238            2238        1647        2238  2238.000000        2238       2238     2238          2238               512     2238      897       0.0             2238                      2238            2238                     381                                               2236     2238  2238.000000   2238   2238.000000           2238            2238  2238.000000
# unique            NaN           NaN         NaN          44          NaN                                      131          84              84                                      131                 NaN                                      130        13          NaN          4               4          14           1          NaN          34        281      285             6               146        2        2       NaN                1                         1             599                      81                                                696        2          NaN    505           NaN            547              18          NaN
# top               NaN           NaN         NaN  California          NaN  Siena College/The New York Times Upshot         134  New York Times  Siena College/The New York Times Upshot                 NaN  Siena College/The New York Times Upshot       B/C          NaN         lv              lv  Live Phone  U.S. House          NaN  District 1    10/3/18  11/4/18       11/6/18    Danny O'Connor    False      DEM       NaN            False                     False  10/30/18 00:15  Democratic surge model  https://www.monmouth.edu/polling-institute/doc...  general          NaN    Kim           NaN    Ben McAdams             DEM          NaN
# freq              NaN           NaN         NaN         202          NaN                                      360         352             352                                      360                 NaN                                      360       703          NaN       1668            1668        1029        2238          NaN         390         50       91          1710                15     1604      616       NaN             2238                      2238              26                      41                                                 25     2231          NaN     30           NaN             20            1006          NaN
# mean     95591.388740  57461.086238  2018.38874         NaN   874.378910                                      NaN         NaN             NaN                                      NaN          266.904613                                      NaN       NaN   505.050984        NaN             NaN         NaN         NaN    10.270331         NaN        NaN      NaN           NaN               NaN      NaN      NaN       NaN              NaN                       NaN             NaN                     NaN                                                NaN      NaN  1967.707775    NaN  12191.861930            NaN             NaN    39.717216
# std      14582.376185   4912.178345     0.78309         NaN   504.710167                                      NaN         NaN             NaN                                      NaN          156.498266                                      NaN       NaN   211.702074        NaN             NaN         NaN         NaN    11.855399         NaN        NaN      NaN           NaN               NaN      NaN      NaN       NaN              NaN                       NaN             NaN                     NaN                                                NaN      NaN  3025.896842    NaN   1306.544489            NaN             NaN    13.823396
# min      80732.000000  51023.000000  2018.00000         NaN    23.000000                                      NaN         NaN             NaN                                      NaN            1.000000                                      NaN       NaN    72.000000        NaN             NaN         NaN         NaN     1.000000         NaN        NaN      NaN           NaN               NaN      NaN      NaN       NaN              NaN                       NaN             NaN                     NaN                                                NaN      NaN   167.000000    NaN  10524.000000            NaN             NaN     0.000000
# 25%      86892.000000  53985.000000  2018.00000         NaN   379.000000                                      NaN         NaN             NaN                                      NaN          118.000000                                      NaN       NaN   400.000000        NaN             NaN         NaN         NaN     2.000000         NaN        NaN      NaN           NaN               NaN      NaN      NaN       NaN              NaN                       NaN             NaN                     NaN                                                NaN      NaN   332.000000    NaN  11220.000000            NaN             NaN    39.000000
# 50%      90286.000000  56205.000000  2018.00000         NaN   940.000000                                      NaN         NaN             NaN                                      NaN          263.000000                                      NaN       NaN   497.000000        NaN             NaN         NaN         NaN     6.000000         NaN        NaN      NaN           NaN               NaN      NaN      NaN       NaN              NaN                       NaN             NaN                     NaN                                                NaN      NaN   456.000000    NaN  11649.000000            NaN             NaN    44.000000
# 75%      91280.750000  56672.000000  2018.00000         NaN  1409.000000                                      NaN         NaN             NaN                                      NaN          448.000000                                      NaN       NaN   533.000000        NaN             NaN         NaN         NaN    13.000000         NaN        NaN      NaN           NaN               NaN      NaN      NaN       NaN              NaN                       NaN             NaN                     NaN                                                NaN      NaN   599.000000    NaN  12587.750000            NaN             NaN    47.000000
# max     129439.000000  69486.000000  2020.00000         NaN  1619.000000                                      NaN         NaN             NaN                                      NaN          615.000000                                      NaN       NaN  2196.000000        NaN             NaN         NaN         NaN    53.000000         NaN        NaN      NaN           NaN               NaN      NaN      NaN       NaN              NaN                       NaN             NaN                     NaN                                                NaN      NaN  8732.000000    NaN  16035.000000            NaN             NaN    72.000000
#
# question_id
# poll_id
# cycle
# state
# pollster_id
# pollster
# sponsor_ids
# sponsors
# display_name
# pollster_rating_id
# pollster_rating_name
# fte_grade
# sample_size
# population
# population_full
# methodology
# office_type
# seat_number
# seat_name
# start_date
# end_date
# election_date
# sponsor_candidate
# internal
# partisan
# tracking
# nationwide_batch
# ranked_choice_reallocated
# created_at
# notes
# url
# stage
# race_id
# answer
# candidate_id
# candidate_name
# candidate_party
# pct

# %%
# Govenor
eda(df_list[2])
# Out:
# Missing Values
#
#  question_id                     0
# poll_id                         0
# cycle                           0
# state                           0
# pollster_id                     0
# pollster                        0
# sponsor_ids                   965
# sponsors                      965
# display_name                    0
# pollster_rating_id              4
# pollster_rating_name            4
# fte_grade                     158
# sample_size                     0
# population                      2
# population_full                 2
# methodology                   286
# office_type                     0
# seat_number                     0
# seat_name                    1949
# start_date                      0
# end_date                        0
# election_date                   0
# sponsor_candidate            1827
# internal                        0
# partisan                     1684
# tracking                     1907
# nationwide_batch                0
# ranked_choice_reallocated       0
# created_at                      0
# notes                        1813
# url                             0
# stage                           0
# race_id                         0
# answer                          0
# candidate_id                    0
# candidate_name                  0
# candidate_party                 0
# pct                             0
# dtype: int64
#
# Duplicate Rows
#  0
#
# Dataframe Types
#
#  question_id                    int64
# poll_id                        int64
# cycle                          int64
# state                         object
# pollster_id                    int64
# pollster                      object
# sponsor_ids                   object
# sponsors                      object
# display_name                  object
# pollster_rating_id           float64
# pollster_rating_name          object
# fte_grade                     object
# sample_size                    int64
# population                    object
# population_full               object
# methodology                   object
# office_type                   object
# seat_number                    int64
# seat_name                    float64
# start_date                    object
# end_date                      object
# election_date                 object
# sponsor_candidate             object
# internal                        bool
# partisan                      object
# tracking                      object
# nationwide_batch                bool
# ranked_choice_reallocated       bool
# created_at                    object
# notes                         object
# url                           object
# stage                         object
# race_id                        int64
# answer                        object
# candidate_id                   int64
# candidate_name                object
# candidate_party               object
# pct                          float64
# dtype: object
#
# Dataframe Shape
#  (1949, 38)
#
# Dataframe Describe
#
#            question_id       poll_id        cycle    state  pollster_id        pollster sponsor_ids  sponsors    display_name  pollster_rating_id pollster_rating_name fte_grade  sample_size population population_full methodology office_type  seat_number  seat_name start_date end_date election_date    sponsor_candidate internal partisan tracking nationwide_batch ranked_choice_reallocated      created_at              notes                               url    stage      race_id    answer  candidate_id candidate_name candidate_party          pct
# count     1949.000000   1949.000000  1949.000000     1949  1949.000000            1949         984       984            1949         1945.000000                 1945      1791  1949.000000       1947            1947        1663        1949       1949.0        0.0       1949     1949          1949                  122     1949      265       42             1949                      1949            1949                136                              1949     1949  1949.000000      1949   1949.000000           1949            1949  1949.000000
# unique            NaN           NaN          NaN       47          NaN             166         141       141             168                 NaN                  164        13          NaN          4               4          11           1          NaN        NaN        291      287             4                   27        2        5        1                1                         1             493                 42                               591        2          NaN       198           NaN            204              20          NaN
# top               NaN           NaN          NaN  Florida          NaN  Marist College         132  NBC News  Marist College                 NaN       Marist College       B/C          NaN         lv              lv  Live Phone    Governor          NaN        NaN    11/1/18  11/4/18       11/6/18  Gretchen E. Whitmer    False      DEM     True            False                     False  10/10/18 10:39  Only 2 candidates  https://www.alliancenrfpoll.com/  general          NaN  DeSantis           NaN   Ron DeSantis             REP          NaN
# freq              NaN           NaN          NaN      143          NaN             106         120       120             106                 NaN                  106       581          NaN       1351            1351         826        1949          NaN        NaN         49       57          1522                   18     1812      158       42             1949                      1949              18                 17                                42     1879          NaN        66           NaN             66             784          NaN
# mean     94651.565418  57187.009749  2018.367881      NaN   888.431503             NaN         NaN       NaN             NaN          252.614910                  NaN       NaN   831.971780        NaN             NaN         NaN         NaN          0.0        NaN        NaN      NaN           NaN                  NaN      NaN      NaN      NaN              NaN                       NaN             NaN                NaN                               NaN      NaN  1743.899436       NaN  12087.727553            NaN             NaN    35.990200
# std      12472.055946   4218.044563     0.728289      NaN   450.929409             NaN         NaN       NaN             NaN          143.678816                  NaN       NaN   444.933689        NaN             NaN         NaN         NaN          0.0        NaN        NaN      NaN           NaN                  NaN      NaN      NaN      NaN              NaN                       NaN             NaN                NaN                               NaN      NaN  3041.726598       NaN   1222.375857            NaN             NaN    17.016104
# min      79648.000000  36742.000000  2018.000000      NaN    23.000000             NaN         NaN       NaN             NaN            1.000000                  NaN       NaN   137.000000        NaN             NaN         NaN         NaN          0.0        NaN        NaN      NaN           NaN                  NaN      NaN      NaN      NaN              NaN                       NaN             NaN                NaN                               NaN      NaN   131.000000       NaN  10430.000000            NaN             NaN     0.000000
# 25%      87230.000000  54058.000000  2018.000000      NaN   458.000000             NaN         NaN       NaN             NaN          133.000000                  NaN       NaN   564.000000        NaN             NaN         NaN         NaN          0.0        NaN        NaN      NaN           NaN                  NaN      NaN      NaN      NaN              NaN                       NaN             NaN                NaN                               NaN      NaN   139.000000       NaN  11115.000000            NaN             NaN    31.000000
# 50%      90548.000000  56330.000000  2018.000000      NaN   988.000000             NaN         NaN       NaN             NaN          245.000000                  NaN       NaN   722.000000        NaN             NaN         NaN         NaN          0.0        NaN        NaN      NaN           NaN                  NaN      NaN      NaN      NaN              NaN                       NaN             NaN                NaN                               NaN      NaN   152.000000       NaN  12399.000000            NaN             NaN    41.600000
# 75%      91489.000000  56779.000000  2018.000000      NaN  1308.000000             NaN         NaN       NaN             NaN          343.000000                  NaN       NaN   966.000000        NaN             NaN         NaN         NaN          0.0        NaN        NaN      NaN           NaN                  NaN      NaN      NaN      NaN              NaN                       NaN             NaN                NaN                               NaN      NaN   165.000000       NaN  13158.000000            NaN             NaN    47.000000
# max     129436.000000  69486.000000  2020.000000      NaN  1606.000000             NaN         NaN       NaN             NaN          603.000000                  NaN       NaN  4830.000000        NaN             NaN         NaN         NaN          0.0        NaN        NaN      NaN           NaN                  NaN      NaN      NaN      NaN              NaN                       NaN             NaN                NaN                               NaN      NaN  8731.000000       NaN  16020.000000            NaN             NaN    68.000000
#
# question_id
# poll_id
# cycle
# state
# pollster_id
# pollster
# sponsor_ids
# sponsors
# display_name
# pollster_rating_id
# pollster_rating_name
# fte_grade
# sample_size
# population
# population_full
# methodology
# office_type
# seat_number
# seat_name
# start_date
# end_date
# election_date
# sponsor_candidate
# internal
# partisan
# tracking
# nationwide_batch
# ranked_choice_reallocated
# created_at
# notes
# url
# stage
# race_id
# answer
# candidate_id
# candidate_name
# candidate_party
# pct

# %%
for frame in df_list:
    frame['start_date'] = pd.to_datetime(frame['start_date'])
    frame['end_date'] = pd.to_datetime(frame['end_date'])
    frame['election_date'] = pd.to_datetime(frame['election_date'])
    frame['created_at'] = pd.to_datetime(frame['created_at'])
    display(frame.dtypes)
# Out:
# question_id                           int64
# poll_id                               int64
# cycle                                 int64
# state                                object
# pollster_id                           int64
# pollster                             object
# sponsor_ids                          object
# sponsors                             object
# display_name                         object
# pollster_rating_id                    int64
# pollster_rating_name                 object
# fte_grade                            object
# sample_size                         float64
# population                           object
# population_full                      object
# methodology                          object
# office_type                          object
# seat_number                           int64
# seat_name                            object
# start_date                   datetime64[ns]
# end_date                     datetime64[ns]
# election_date                datetime64[ns]
# sponsor_candidate                    object
# internal                               bool
# partisan                             object
# tracking                             object
# nationwide_batch                       bool
# ranked_choice_reallocated              bool
# created_at                   datetime64[ns]
# notes                                object
# url                                  object
# stage                                object
# race_id                               int64
# answer                               object
# candidate_id                          int64
# candidate_name                       object
# candidate_party                      object
# pct                                 float64
# dtype: object
# question_id                           int64
# poll_id                               int64
# cycle                                 int64
# state                                object
# pollster_id                           int64
# pollster                             object
# sponsor_ids                          object
# sponsors                             object
# display_name                         object
# pollster_rating_id                  float64
# pollster_rating_name                 object
# fte_grade                            object
# sample_size                         float64
# population                           object
# population_full                      object
# methodology                          object
# office_type                          object
# seat_number                           int64
# seat_name                            object
# start_date                   datetime64[ns]
# end_date                     datetime64[ns]
# election_date                datetime64[ns]
# sponsor_candidate                    object
# internal                               bool
# partisan                             object
# tracking                            float64
# nationwide_batch                       bool
# ranked_choice_reallocated              bool
# created_at                   datetime64[ns]
# notes                                object
# url                                  object
# stage                                object
# race_id                               int64
# answer                               object
# candidate_id                          int64
# candidate_name                       object
# candidate_party                      object
# pct                                 float64
# dtype: object
# question_id                           int64
# poll_id                               int64
# cycle                                 int64
# state                                object
# pollster_id                           int64
# pollster                             object
# sponsor_ids                          object
# sponsors                             object
# display_name                         object
# pollster_rating_id                  float64
# pollster_rating_name                 object
# fte_grade                            object
# sample_size                           int64
# population                           object
# population_full                      object
# methodology                          object
# office_type                          object
# seat_number                           int64
# seat_name                           float64
# start_date                   datetime64[ns]
# end_date                     datetime64[ns]
# election_date                datetime64[ns]
# sponsor_candidate                    object
# internal                               bool
# partisan                             object
# tracking                             object
# nationwide_batch                       bool
# ranked_choice_reallocated              bool
# created_at                   datetime64[ns]
# notes                                object
# url                                  object
# stage                                object
# race_id                               int64
# answer                               object
# candidate_id                          int64
# candidate_name                       object
# candidate_party                      object
# pct                                 float64
# dtype: object

# %%
df_gov.groupby(['state', 'candidate_party'])['pct'].mean()
# Out:
# state           candidate_party
# Alabama         DEM                33.000000
#                 REP                54.000000
# Alaska          DEM                35.962500
#                 IND                29.526667
#                 LIB                 3.300000
#                 REP                42.847619
# Arizona         DEM                39.415000
#                 GRE                 3.625000
#                 LIB                 1.600000
#                 REP                50.941923
# Arkansas        DEM                27.000000
#                 LIB                 5.500000
#                 REP                60.500000
# California      DEM                51.026667
#                 REP                36.386667
# Colorado        DEM                47.000000
#                 IND                 0.500000
#                 LIB                 3.000000
#                 REP                39.250000
# Connecticut     DEM                44.791667
#                 IND                 8.328571
#                 LIB                 0.700000
#                 REP                38.016667
# Florida         DEM                47.425758
#                 NPA                 0.400000
#                 REF                 1.862500
#                 REP                43.537576
# Georgia         DEM                45.566667
#                 LIB                 2.442857
#                 REP                45.554167
# Hawaii          DEM                53.333333
#                 REP                29.666667
# Idaho           CON                 2.000000
#                 DEM                31.500000
#                 LIB                 4.000000
#                 REP                43.000000
# Illinois        CON                 6.850000
#                 CRV                 6.416667
#                 DEM                44.936842
#                 LIB                 3.691667
#                 REP                29.247368
# Indiana         DEM                25.000000
#                 LIB                16.000000
#                 REP                49.500000
# Iowa            DEM                43.401250
#                 IND                 1.000000
#                 LIB                 4.000000
#                 REP                41.690000
# Kansas          DEM                39.658333
#                 IND                 6.812500
#                 LIB                 2.200000
#                 REP                39.133333
# Kentucky        DEM                47.350000
#                 LIB                 3.516667
#                 REP                42.340000
# Louisiana       DEM                47.998000
#                 REP                39.612286
# Maine           DEM                46.816667
#                 IND                 5.114286
#                 REP                38.600000
# Maryland        DEM                35.461538
#                 GRE                 0.925000
#                 LIB                 1.100000
#                 REP                51.492308
# Massachusetts   DEM                24.015385
#                 REP                61.753846
# Michigan        DEM                46.291892
#                 GRE                 1.714286
#                 LIB                 2.345455
#                 NLP                 0.900000
#                 REP                38.148649
#                 UST                 1.166667
# Minnesota       DEM                48.435714
#                 GRT                 2.120000
#                 LIB                 3.228571
#                 REP                38.614286
# Mississippi     CON                 2.000000
#                 DEM                41.459444
#                 IND                 5.980000
#                 REP                44.166111
# Missouri        DEM                38.213636
#                 GRE                 1.900000
#                 LIB                 2.500000
#                 REP                49.550000
# Montana         DEM                41.852000
#                 REP                47.010000
# Nevada          DEM                42.884412
#                 IAP                 2.266667
#                 IND                 3.300000
#                 LIB                 4.444444
#                 REP                42.868824
# New Hampshire   DEM                31.646818
#                 LIB                 1.814444
#                 REP                54.005909
# New Mexico      DEM                50.125333
#                 IND                 3.050000
#                 REP                42.646667
# New York        DEM                51.937500
#                 GRE                 4.250000
#                 IND                 7.400000
#                 LIB                 7.000000
#                 OTH                14.000000
#                 REP                32.062500
# North Carolina  CON                 0.637500
#                 DEM                49.462222
#                 LIB                 1.175000
#                 REP                38.029259
# North Dakota    DEM                33.000000
#                 REP                62.000000
# Ohio            DEM                41.547059
#                 GRE                 2.290000
#                 IND                 2.800000
#                 LIB                 3.875000
#                 REP                43.052941
#                 W                   0.133333
# Oklahoma        DEM                41.300000
#                 LIB                 2.783333
#                 REP                43.222222
# Oregon          CON                 1.000000
#                 DEM                43.745455
#                 IND                 4.000000
#                 LIB                 1.333333
#                 PRO                 1.000000
#                 REP                39.418182
# Pennsylvania    DEM                51.264000
#                 GRE                 1.000000
#                 LIB                 2.000000
#                 REP                34.092000
# Puerto Rico     IND                 6.166667
#                 NPP                41.200000
#                 PPD                20.200000
#                 PRI                 9.200000
# Rhode Island    DEM                40.812500
#                 IND                 4.643750
#                 OTH                 1.500000
#                 REP                35.862500
# South Carolina  DEM                38.180000
#                 REP                51.900000
# South Dakota    DEM                44.800000
#                 LIB                 1.750000
#                 REP                46.514286
# Tennessee       DEM                38.642069
#                 REP                52.462069
# Texas           DEM                36.105000
#                 LIB                 2.507143
#                 REP                52.019000
# Utah            DEM                18.300000
#                 IAP                 2.900000
#                 LIB                 4.000000
#                 REP                52.000000
# Vermont         DEM                29.000000
#                 IND                 0.750000
#                 LBU                 1.000000
#                 REP                52.857143
# Washington      DEM                59.222222
#                 REP                31.555556
# West Virginia   DEM                49.000000
#                 REP                39.000000
# Wisconsin       DEM                47.504000
#                 GRE                 1.800000
#                 IND                 0.500000
#                 LIB                 4.872727
#                 REP                43.940000
# Wyoming         CON                 6.000000
#                 DEM                27.000000
#                 LIB                 4.000000
#                 REP                61.000000
# Name: pct, dtype: float64

# %%
for frame in df_list:
    display(frame.groupby(['state', 'candidate_party'])['pct'].mean())
# Out:
# state           candidate_party
# Alabama         DEM                40.511765
#                 IND                 2.300000
#                 REP                46.305882
# Alaska          DEM                39.000000
#                 IND                40.000000
#                 REP                43.200000
# Arizona         DEM                48.375033
#                 GRE                 3.604167
#                 LIB                 2.300000
#                 REP                42.083974
# California      DEM                34.720455
# Colorado        DEM                49.855000
#                 REP                40.235833
# Connecticut     DEM                56.516667
#                 REP                36.850000
# Delaware        DEM                56.000000
#                 GRE                 2.500000
#                 LIB                 4.000000
#                 REP                28.333333
# Florida         DEM                45.599192
#                 REP                45.107778
# Georgia         DEM                22.776042
#                 IND                 2.966667
#                 LIB                 4.288333
#                 REP                31.046667
# Idaho           DEM                27.720000
#                 REP                53.360000
# Illinois        DEM                44.300000
#                 IND                25.000000
# Indiana         DEM                44.085000
#                 LIB                 6.117647
#                 REP                43.555000
# Iowa            DEM                43.978235
#                 IND                 1.000000
#                 LIB                 2.000000
#                 REP                45.608235
# Kansas          DEM                41.808333
#                 REP                43.583333
# Kentucky        DEM                40.224286
#                 LIB                 5.428571
#                 REP                47.663571
# Maine           DEM                37.031481
#                 IND                21.223846
#                 REP                41.141481
# Maryland        DEM                52.700000
#                 IND                12.850000
#                 LIB                 1.000000
#                 REP                19.250000
# Massachusetts   DEM                51.976471
#                 IND                 6.840000
#                 REP                33.094118
# Michigan        DEM                48.928065
#                 GRE                 2.040000
#                 NLP                 0.575000
#                 REP                38.933333
#                 UST                 1.050000
# Minnesota       DEM                50.673243
#                 GRE                 2.400000
#                 IND                 2.240000
#                 REP                36.354324
# Mississippi     DEM                30.232955
#                 LIB                 2.803333
#                 REF                 1.635000
#                 REP                36.696383
# Missouri        DEM                45.105714
#                 GRE                 1.444444
#                 IND                 2.500000
#                 LIB                 2.111111
#                 REP                45.595714
# Montana         DEM                48.955833
#                 LIB                 2.750000
#                 REP                43.843056
# Nebraska        DEM                34.666667
#                 REP                49.000000
# Nevada          DEM                44.756591
#                 IAP                 1.100000
#                 IND                 1.900000
#                 LIB                 4.400000
#                 REP                43.981364
# New Hampshire   DEM                50.723810
#                 LIB                 3.500000
#                 REP                36.628571
# New Jersey      DEM                48.164815
#                 GRE                 1.000000
#                 LIB                 2.716667
#                 REP                38.194074
# New Mexico      DEM                46.344118
#                 LIB                17.814667
#                 REP                29.127500
# New York        DEM                58.333333
#                 REP                29.666667
# North Carolina  CON                 1.592308
#                 DEM                44.811746
#                 LIB                 2.676923
#                 REP                40.600952
# North Dakota    DEM                43.527778
#                 REP                50.750000
# Ohio            DEM                49.396970
#                 GRE                 2.500000
#                 LIB                 5.000000
#                 REP                38.566667
#                 W                   1.200000
# Oklahoma        DEM                32.600000
#                 IND                 0.600000
#                 LIB                 2.300000
#                 REP                54.766667
# Pennsylvania    DEM                50.541034
#                 GRE                 1.500000
#                 LIB                 1.250000
#                 REP                36.269655
# Rhode Island    DEM                55.260000
#                 REP                33.660000
# South Carolina  CON                 3.000000
#                 DEM                40.687500
#                 LIB                 4.000000
#                 REP                48.375000
# Tennessee       DEM                43.378704
#                 REP                47.135741
# Texas           DEM                38.901667
#                 GRE                 2.333333
#                 IND                 6.000000
#                 LIB                 2.044615
#                 REP                45.671538
# Utah            CON                 2.950000
#                 DEM                22.371429
#                 IAP                 2.350000
#                 LIB                 2.700000
#                 REP                61.514286
# Vermont         IND                40.600000
#                 REP                23.000000
# Virginia        DEM                51.784615
#                 LIB                 4.750000
#                 REP                34.823077
# Washington      DEM                52.500000
#                 REP                37.500000
# West Virginia   DEM                49.051282
#                 IND                 6.000000
#                 LIB                 4.720000
#                 REP                40.412821
# Wisconsin       DEM                52.353571
#                 REP                40.203571
# Wyoming         DEM                31.000000
#                 LIB                 6.000000
#                 REP                60.000000
# Name: pct, dtype: float64
# state           candidate_party
# Alaska          DEM                43.744444
#                 REP                46.411111
# Arizona         DEM                42.250500
#                 GRE                 2.000000
#                 REP                45.637000
# Arkansas        DEM                35.000000
#                 LIB                 3.400000
#                 REP                51.357143
# California      DEM                44.725941
#                 REP                45.757723
# Colorado        DEM                44.654375
#                 IND                 3.000000
#                 LIB                 5.666667
#                 REP                42.086250
#                 UNI                 1.000000
# Delaware        DEM                51.000000
#                 REP                32.750000
# Florida         DEM                42.590526
#                 NPA                 5.000000
#                 REP                45.725439
# Georgia         DEM                44.076000
#                 REP                47.328667
# Idaho           CON                 6.000000
#                 DEM                25.000000
#                 LIB                10.000000
#                 REP                47.000000
# Illinois        DEM                42.398438
#                 GRE                 8.000000
#                 REP                44.766563
# Indiana         DEM                44.428571
#                 LIB                 4.500000
#                 REP                47.571429
# Iowa            DEM                43.252400
#                 IND                 1.833333
#                 LIB                 3.254545
#                 REP                43.134400
# Kansas          DEM                39.908000
#                 LIB                 3.100000
#                 REP                43.819600
# Kentucky        DEM                46.542857
#                 LIB                 2.000000
#                 REP                45.529286
# Louisiana       DEM                 4.050000
#                 LIB                 1.400000
#                 REP                37.250000
# Maine           DEM                45.691176
#                 IND                 6.700000
#                 REP                36.885294
# Michigan        DEM                42.309167
#                 IND                 1.333333
#                 LIB                 3.000000
#                 REP                42.358889
#                 UST                 1.333333
# Minnesota       DEM                44.706667
#                 OTH                 6.000000
#                 REP                43.227333
# Mississippi     DEM                35.597500
#                 REF                22.130000
#                 REP                55.653333
# Missouri        DEM                42.000000
#                 GRE                 0.000000
#                 LIB                 1.000000
#                 REP                46.000000
# Montana         DEM                45.087500
#                 LIB                 2.440000
#                 REP                46.493750
# Nebraska        DEM                43.675000
#                 REP                50.109000
# Nevada          DEM                42.130769
#                 IAP                 2.500000
#                 IND                 1.000000
#                 LIB                 2.500000
#                 N                   2.000000
#                 REP                36.815385
# New Hampshire   DEM                49.623529
#                 LIB                 1.907143
#                 REP                35.464706
# New Jersey      DEM                45.242157
#                 GRE                 0.400000
#                 IND                 0.600000
#                 LIB                 2.400000
#                 OTH                 5.000000
#                 REP                41.910588
# New Mexico      DEM                47.174400
#                 LIB                 3.350000
#                 REP                42.561600
# New York        DEM                43.404355
#                 GRE                 1.250000
#                 IND                 4.000000
#                 REF                 3.666667
#                 REP                44.990806
# North Carolina  CON                 1.000000
#                 DEM                43.047667
#                 GRE                 1.350000
#                 LIB                 2.428571
#                 REP                43.765333
# North Dakota    DEM                32.636364
#                 REP                50.909091
# Ohio            DEM                42.287368
#                 GRE                 2.142857
#                 LIB                 4.000000
#                 REP                47.651316
# Oklahoma        DEM                36.783333
#                 IND                 5.950000
#                 LIB                 3.900000
#                 REP                49.383333
# Oregon          DEM                36.500000
#                 IND                 7.000000
#                 REP                52.500000
# Pennsylvania    DEM                45.425072
#                 LIB                 2.800000
#                 REP                45.221014
# Puerto Rico     IND                 5.333333
#                 NPP                40.500000
#                 PPD                27.000000
#                 PRI                 5.500000
# South Carolina  DEM                42.953333
#                 REP                46.290000
# South Dakota    DEM                35.180000
#                 IND                 2.500000
#                 LIB                 1.500000
#                 REP                51.200000
# Texas           DEM                41.186981
#                 IND                 3.000000
#                 LIB                 5.611111
#                 REP                45.955660
# Utah            CON                 2.200000
#                 DEM                34.921818
#                 GRE                 2.333333
#                 IND                 4.688889
#                 LIB                 4.437500
#                 OTH                 2.600000
#                 REP                47.865152
#                 UNI                 0.850000
# Vermont         DEM                60.500000
#                 IND                 3.000000
#                 LBU                 3.000000
#                 REP                23.000000
# Virginia        DEM                46.795417
#                 LIB                 2.000000
#                 REP                44.459167
# Washington      DEM                40.432222
#                 REP                46.048125
# West Virginia   DEM                36.884783
#                 MTP                 3.700000
#                 REP                48.886087
# Wisconsin       DEM                42.283000
#                 IND                 6.500000
#                 REP                47.967000
# Wyoming         CON                 6.000000
#                 DEM                28.000000
#                 LIB                 7.000000
#                 REP                55.000000
# Name: pct, dtype: float64
# state           candidate_party
# Alabama         DEM                33.000000
#                 REP                54.000000
# Alaska          DEM                35.962500
#                 IND                29.526667
#                 LIB                 3.300000
#                 REP                42.847619
# Arizona         DEM                39.415000
#                 GRE                 3.625000
#                 LIB                 1.600000
#                 REP                50.941923
# Arkansas        DEM                27.000000
#                 LIB                 5.500000
#                 REP                60.500000
# California      DEM                51.026667
#                 REP                36.386667
# Colorado        DEM                47.000000
#                 IND                 0.500000
#                 LIB                 3.000000
#                 REP                39.250000
# Connecticut     DEM                44.791667
#                 IND                 8.328571
#                 LIB                 0.700000
#                 REP                38.016667
# Florida         DEM                47.425758
#                 NPA                 0.400000
#                 REF                 1.862500
#                 REP                43.537576
# Georgia         DEM                45.566667
#                 LIB                 2.442857
#                 REP                45.554167
# Hawaii          DEM                53.333333
#                 REP                29.666667
# Idaho           CON                 2.000000
#                 DEM                31.500000
#                 LIB                 4.000000
#                 REP                43.000000
# Illinois        CON                 6.850000
#                 CRV                 6.416667
#                 DEM                44.936842
#                 LIB                 3.691667
#                 REP                29.247368
# Indiana         DEM                25.000000
#                 LIB                16.000000
#                 REP                49.500000
# Iowa            DEM                43.401250
#                 IND                 1.000000
#                 LIB                 4.000000
#                 REP                41.690000
# Kansas          DEM                39.658333
#                 IND                 6.812500
#                 LIB                 2.200000
#                 REP                39.133333
# Kentucky        DEM                47.350000
#                 LIB                 3.516667
#                 REP                42.340000
# Louisiana       DEM                47.998000
#                 REP                39.612286
# Maine           DEM                46.816667
#                 IND                 5.114286
#                 REP                38.600000
# Maryland        DEM                35.461538
#                 GRE                 0.925000
#                 LIB                 1.100000
#                 REP                51.492308
# Massachusetts   DEM                24.015385
#                 REP                61.753846
# Michigan        DEM                46.291892
#                 GRE                 1.714286
#                 LIB                 2.345455
#                 NLP                 0.900000
#                 REP                38.148649
#                 UST                 1.166667
# Minnesota       DEM                48.435714
#                 GRT                 2.120000
#                 LIB                 3.228571
#                 REP                38.614286
# Mississippi     CON                 2.000000
#                 DEM                41.459444
#                 IND                 5.980000
#                 REP                44.166111
# Missouri        DEM                38.213636
#                 GRE                 1.900000
#                 LIB                 2.500000
#                 REP                49.550000
# Montana         DEM                41.852000
#                 REP                47.010000
# Nevada          DEM                42.884412
#                 IAP                 2.266667
#                 IND                 3.300000
#                 LIB                 4.444444
#                 REP                42.868824
# New Hampshire   DEM                31.646818
#                 LIB                 1.814444
#                 REP                54.005909
# New Mexico      DEM                50.125333
#                 IND                 3.050000
#                 REP                42.646667
# New York        DEM                51.937500
#                 GRE                 4.250000
#                 IND                 7.400000
#                 LIB                 7.000000
#                 OTH                14.000000
#                 REP                32.062500
# North Carolina  CON                 0.637500
#                 DEM                49.462222
#                 LIB                 1.175000
#                 REP                38.029259
# North Dakota    DEM                33.000000
#                 REP                62.000000
# Ohio            DEM                41.547059
#                 GRE                 2.290000
#                 IND                 2.800000
#                 LIB                 3.875000
#                 REP                43.052941
#                 W                   0.133333
# Oklahoma        DEM                41.300000
#                 LIB                 2.783333
#                 REP                43.222222
# Oregon          CON                 1.000000
#                 DEM                43.745455
#                 IND                 4.000000
#                 LIB                 1.333333
#                 PRO                 1.000000
#                 REP                39.418182
# Pennsylvania    DEM                51.264000
#                 GRE                 1.000000
#                 LIB                 2.000000
#                 REP                34.092000
# Puerto Rico     IND                 6.166667
#                 NPP                41.200000
#                 PPD                20.200000
#                 PRI                 9.200000
# Rhode Island    DEM                40.812500
#                 IND                 4.643750
#                 OTH                 1.500000
#                 REP                35.862500
# South Carolina  DEM                38.180000
#                 REP                51.900000
# South Dakota    DEM                44.800000
#                 LIB                 1.750000
#                 REP                46.514286
# Tennessee       DEM                38.642069
#                 REP                52.462069
# Texas           DEM                36.105000
#                 LIB                 2.507143
#                 REP                52.019000
# Utah            DEM                18.300000
#                 IAP                 2.900000
#                 LIB                 4.000000
#                 REP                52.000000
# Vermont         DEM                29.000000
#                 IND                 0.750000
#                 LBU                 1.000000
#                 REP                52.857143
# Washington      DEM                59.222222
#                 REP                31.555556
# West Virginia   DEM                49.000000
#                 REP                39.000000
# Wisconsin       DEM                47.504000
#                 GRE                 1.800000
#                 IND                 0.500000
#                 LIB                 4.872727
#                 REP                43.940000
# Wyoming         CON                 6.000000
#                 DEM                27.000000
#                 LIB                 4.000000
#                 REP                61.000000
# Name: pct, dtype: float64

# %%
for frame in df_list:
#     print(f'This is the {} DataFrame of information'.format(frame))
    display(frame['state'].value_counts(dropna=False))
# Out:
# Arizona           315
# Michigan          199
# Florida           198
# Georgia           189
# Missouri          188
# Texas             173
# North Carolina    152
# Tennessee         108
# Mississippi       101
# Nevada            100
# Indiana            97
# Minnesota          96
# West Virginia      93
# Montana            78
# Ohio               72
# Maine              67
# Pennsylvania       66
# New Jersey         63
# Wisconsin          56
# New Mexico         48
# Massachusetts      44
# California         44
# New Hampshire      44
# North Dakota       36
# Iowa               36
# Alabama            36
# Kentucky           35
# South Carolina     34
# Virginia           30
# Colorado           24
# Kansas             24
# Utah               20
# New York           18
# Connecticut        12
# Rhode Island       10
# Delaware           10
# Alaska             10
# Oklahoma            9
# Vermont             8
# Maryland            7
# Nebraska            6
# Washington          4
# Wyoming             3
# Idaho               2
# Illinois            2
# Name: state, dtype: int64
# California        202
# Pennsylvania      147
# New York          137
# Florida           117
# Iowa              117
# Texas             116
# New Jersey        108
# Virginia          101
# Ohio               93
# Utah               92
# Michigan           86
# North Carolina     83
# Illinois           65
# Minnesota          61
# New Mexico         56
# Kansas             56
# New Hampshire      48
# West Virginia      47
# Arizona            41
# Maine              38
# Colorado           38
# Montana            37
# Washington         34
# Nevada             33
# Georgia            30
# Kentucky           29
# Oklahoma           27
# North Dakota       22
# Wisconsin          21
# Nebraska           20
# Arkansas           19
# Alaska             18
# Indiana            16
# South Dakota       14
# Missouri           10
# Puerto Rico         9
# Mississippi         8
# Delaware            8
# Louisiana           7
# South Carolina      6
# Idaho               6
# Vermont             6
# Oregon              5
# Wyoming             4
# Name: state, dtype: int64
# Florida           143
# North Carolina    124
# Arizona           115
# Michigan           98
# Ohio               90
# Nevada             82
# Louisiana          70
# Texas              67
# Wisconsin          66
# Illinois           62
# Georgia            62
# California         60
# Tennessee          58
# New Hampshire      53
# Alaska             53
# Pennsylvania       48
# Missouri           46
# Kansas             45
# New York           45
# Mississippi        41
# Minnesota          40
# Rhode Island       37
# Puerto Rico        36
# Maryland           34
# Oregon             33
# Connecticut        33
# New Mexico         32
# Massachusetts      26
# Kentucky           26
# Colorado           25
# Oklahoma           24
# Iowa               20
# Maine              19
# Vermont            19
# Washington         18
# South Dakota       18
# Idaho              11
# Arkansas           10
# South Carolina     10
# Montana            10
# Indiana            10
# Alabama             8
# Utah                8
# Hawaii              6
# Wyoming             4
# West Virginia       2
# North Dakota        2
# Name: state, dtype: int64

# %%
df_senate['state'].nunique()
# Out:
# 45

# %%
df_gov['state'].nunique()
# Out:
# 47

# %%
df_house['state'].nunique()
# Out:
# 44

# %%
df_senate['candidate_party'].value_counts()
# Out:
# DEM    1353
# REP    1302
# LIB     147
# IND      75
# GRE      56
# CON      16
# IAP       4
# UST       4
# REF       4
# NLP       4
# W         2
# Name: candidate_party, dtype: int64

# %% [markdown]
# **Idea Notes** <br>
#
# - Create time series by state to see if there's a change by political part / candidate
# - Create overall charts showing the `mean`, perhaps `max`, `min`, `mode`
